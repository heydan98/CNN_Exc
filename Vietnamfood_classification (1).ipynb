# %%
# !pip install opendatasets
# !pip install pandas
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting opendatasets
#   Downloading opendatasets-0.1.22-py3-none-any.whl (15 kB)
# Requirement already satisfied: kaggle in /usr/local/lib/python3.7/dist-packages (from opendatasets) (1.5.12)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from opendatasets) (7.1.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from opendatasets) (4.64.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2.23.0)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (6.1.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2.8.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (2022.9.24)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (1.15.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.7/dist-packages (from kaggle->opendatasets) (1.24.3)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.7/dist-packages (from python-slugify->kaggle->opendatasets) (1.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle->opendatasets) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->kaggle->opendatasets) (3.0.4)
# Installing collected packages: opendatasets
# Successfully installed opendatasets-0.1.22
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (1.3.5)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2022.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)

# %%
import opendatasets as od
import pandas
od.download(
    "https://www.kaggle.com/datasets/quandang/vietnamese-foods",force = True)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: heydan98
# Your Kaggle Key: ··········
# Downloading vietnamese-foods.zip to ./vietnamese-foods
# 100%|██████████| 4.17G/4.17G [04:47<00:00, 15.6MB/s]

# %%
cd /content/vietnamese-foods/Images/Train
# Out:
# /content/vietnamese-foods/Images/Train

# %%
ls
# Out:
# 'Banh beo'/      'Banh khot'/         'Bun mam'/         'Goi cuon'/
# 'Banh bot loc'/  'Banh mi'/           'Bun rieu'/        'Hu tieu'/
# 'Banh can'/      'Banh pia'/          'Bun thit nuong'/  'Mi quang'/
# 'Banh canh'/     'Banh tet'/          'Ca kho to'/       'Nem chua'/
# 'Banh chung'/    'Banh trang nuong'/  'Canh chua'/        Pho/
# 'Banh cuon'/     'Banh xeo'/          'Cao lau'/         'Xoi xeo'/
# 'Banh duc'/      'Bun bo Hue'/        'Chao long'/
# 'Banh gio'/      'Bun dau mam tom'/   'Com tam'/

# %%
import shutil
shutil.rmtree('Banh beo')
shutil.rmtree('Banh bot loc')
shutil.rmtree('Banh can')     
shutil.rmtree('Banh khot')
shutil.rmtree('Bun mam')         
shutil.rmtree('Goi cuon')  
shutil.rmtree('Banh mi') 
shutil.rmtree('Bun rieu')        
shutil.rmtree('Hu tieu')
shutil.rmtree('Banh pia')
shutil.rmtree('Bun thit nuong')
shutil.rmtree('Mi quang')
shutil.rmtree('Banh canh')    
shutil.rmtree('Banh tet')          
shutil.rmtree('Ca kho to')
shutil.rmtree('Nem chua')
shutil.rmtree('Banh chung')    
shutil.rmtree('Banh trang nuong')
shutil.rmtree('Canh chua')
shutil.rmtree("Pho")
shutil.rmtree('Banh cuon')
shutil.rmtree('Cao lau')

# %%
ls
# Out:
# 'Banh duc'/  'Banh xeo'/    'Bun dau mam tom'/  'Com tam'/
# 'Banh gio'/  'Bun bo Hue'/  'Chao long'/        'Xoi xeo'/

# %%
from keras.preprocessing.image import ImageDataGenerator

train_datagen = ImageDataGenerator(rotation_range=10,  
                             zoom_range = 0.1,  
                             width_shift_range=0.1, 
                             height_shift_range=0.1,
                             brightness_range=(0.9, 1.1),
                             rescale=1/255.0)

valid_datagen = ImageDataGenerator(rescale=1/255.0)

test_datagen = ImageDataGenerator(rescale=1/255.0)

# %%
im_size = 224
batch_size = 64

train_generator = train_datagen.flow_from_directory(
    directory=r"./",
    target_size=(im_size, im_size),
    color_mode="rgb",
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=True,
    seed=42
)
# Out:
# Found 5219 images belonging to 8 classes.

# %%
for image in train_generator:
  print(type(image))
  print(type(image[0]))
  print(image[0].shape)
  break
# Out:
# <class 'tuple'>
# <class 'numpy.ndarray'>
# (64, 224, 224, 3)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.imshow(image[0][9])

# %%
valid_generator = valid_datagen.flow_from_directory(
    directory=r"./",
    target_size=(im_size, im_size),
    color_mode="rgb",
    batch_size=batch_size,
    class_mode="categorical",
    shuffle=False,
    seed=42
)
# Out:
# Found 5219 images belonging to 8 classes.

# %%
STEP_SIZE_TRAIN=train_generator.n//train_generator.batch_size
STEP_SIZE_VALID=valid_generator.n//valid_generator.batch_size

# %%
ls
# Out:
# 'Banh duc'/  'Banh xeo'/    'Bun dau mam tom'/  'Com tam'/
# 'Banh gio'/  'Bun bo Hue'/  'Chao long'/        'Xoi xeo'/

# %%
from pathlib import Path
path = Path('/content/vietnamese-foods/Images/Train')
class_names = list(path.glob('*'))
for class_name in class_names:
  print(class_name)
# Out:
# /content/vietnamese-foods/Images/Train/Com tam
# /content/vietnamese-foods/Images/Train/Banh gio
# /content/vietnamese-foods/Images/Train/Bun dau mam tom
# /content/vietnamese-foods/Images/Train/Bun bo Hue
# /content/vietnamese-foods/Images/Train/Chao long
# /content/vietnamese-foods/Images/Train/Banh duc
# /content/vietnamese-foods/Images/Train/Banh xeo
# /content/vietnamese-foods/Images/Train/Xoi xeo

# %%
cd /content/vietnamese-foods/Images/Train
# Out:
# /content/vietnamese-foods/Images/Train

# %%
ls
# Out:
# 'Banh duc'/  'Banh xeo'/    'Bun dau mam tom'/  'Com tam'/
# 'Banh gio'/  'Bun bo Hue'/  'Chao long'/        'Xoi xeo'/

# %%
import cv2
X = []
y = []
food = ['Banh xeo', 'Banh gio', 'Bun dau mam tom', 'Bun bo Hue', 'Chao long', 'Com tam', 'Xoi xeo', 'Banh duc']
# food.index('dandelion')
for class_name in class_names:
  print(class_name)
  images_path = list(class_name.glob('*'))
  for im_path in images_path:
    img = cv2.imread(str(im_path))
    # img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    img = cv2.resize(img, (64,64))
    label = food.index(str(class_name).split('/')[-1])
    X.append(img)
    y.append(label)
# Out:
# /content/vietnamese-foods/Images/Train/Com tam
# /content/vietnamese-foods/Images/Train/Banh gio
# /content/vietnamese-foods/Images/Train/Bun dau mam tom
# /content/vietnamese-foods/Images/Train/Bun bo Hue
# /content/vietnamese-foods/Images/Train/Chao long
# /content/vietnamese-foods/Images/Train/Banh duc
# /content/vietnamese-foods/Images/Train/Banh xeo
# /content/vietnamese-foods/Images/Train/Xoi xeo

# %%
from keras.utils import to_categorical
y = to_categorical(y)
print(y.shape)
# Out:
# (5219, 8)

# %%
import numpy as np
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(np.array(X), np.array(y), test_size=0.2)

# %%
# X_train = X_train.reshape(60000, 28*28)
X_train = X_train.astype('float32')/255
# X_test = X_test.reshape(10000, 28*28)
X_test = X_test.astype('float32')/255

# %%
plt.imshow(X_train[5])
print(y_train[5])
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# [0. 0. 0. 0. 0. 1. 0. 0.]
# (4175, 64, 64, 3)
# (1044, 64, 64, 3)
# (4175, 8)
# (1044, 8)

# %%
import matplotlib.pyplot as plt
from keras import models
from keras import layers
from keras.utils import to_categorical
import cv2
import numpy as np
from keras import models, layers
from keras.layers import Flatten, Dense, Activation
from keras.layers import Conv2D, MaxPooling2D
from keras.models import Sequential,Model
model = Sequential()
model.add(Conv2D(32,kernel_size=(3,3), activation='relu',input_shape=(64,64,3),padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(64,kernel_size=(3,3), activation='relu',padding='same'))
model.add(MaxPooling2D(2,2))
model.add(Conv2D(128,kernel_size=(3,3), activation='relu',padding='same'))
model.add(MaxPooling2D(2,2))

model.add(Flatten())
model.add(Dense(128,activation='relu'))
model.add(Dense(8,activation='softmax'))
model.summary()
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 64, 64, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 16, 16, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 8, 8, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 8192)              0
#
#  dense (Dense)               (None, 128)               1048704
#
#  dense_1 (Dense)             (None, 8)                 1032
#
# =================================================================
# Total params: 1,142,984
# Trainable params: 1,142,984
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_train,y_train,epochs=200,batch_size=128)
# Out:
# Epoch 1/200
# 33/33 [==============================] - 9s 26ms/step - loss: 2.0223 - accuracy: 0.2297
# Epoch 2/200
# 33/33 [==============================] - 1s 19ms/step - loss: 1.8386 - accuracy: 0.3248
# Epoch 3/200
# 33/33 [==============================] - 1s 19ms/step - loss: 1.6586 - accuracy: 0.4034
# Epoch 4/200
# 33/33 [==============================] - 1s 19ms/step - loss: 1.5471 - accuracy: 0.4572
# Epoch 5/200
# 33/33 [==============================] - 1s 19ms/step - loss: 1.3792 - accuracy: 0.5193
# Epoch 6/200
# 33/33 [==============================] - 1s 19ms/step - loss: 1.2752 - accuracy: 0.5657
# Epoch 7/200
# 33/33 [==============================] - 1s 19ms/step - loss: 1.1758 - accuracy: 0.5909
# Epoch 8/200
# 33/33 [==============================] - 1s 19ms/step - loss: 1.0595 - accuracy: 0.6450
# Epoch 9/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.9580 - accuracy: 0.6759
# Epoch 10/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.8683 - accuracy: 0.7011
# Epoch 11/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.7848 - accuracy: 0.7332
# Epoch 12/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.6805 - accuracy: 0.7717
# Epoch 13/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.5704 - accuracy: 0.8144
# Epoch 14/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.4838 - accuracy: 0.8331
# Epoch 15/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.4196 - accuracy: 0.8613
# Epoch 16/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.3369 - accuracy: 0.8953
# Epoch 17/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.2439 - accuracy: 0.9222
# Epoch 18/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.2422 - accuracy: 0.9289
# Epoch 19/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.2144 - accuracy: 0.9351
# Epoch 20/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1559 - accuracy: 0.9655
# Epoch 21/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.1749 - accuracy: 0.9564
# Epoch 22/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1876 - accuracy: 0.9514
# Epoch 23/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1803 - accuracy: 0.9631
# Epoch 24/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0251 - accuracy: 0.9978
# Epoch 25/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.1870 - accuracy: 0.9629
# Epoch 26/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.1063 - accuracy: 0.9746
# Epoch 27/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0928 - accuracy: 0.9749
# Epoch 28/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0859 - accuracy: 0.9801
# Epoch 29/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1870 - accuracy: 0.9619
# Epoch 30/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0604 - accuracy: 0.9820
# Epoch 31/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.1321 - accuracy: 0.9751
# Epoch 32/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0134 - accuracy: 0.9986
# Epoch 33/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.1095 - accuracy: 0.9770
# Epoch 34/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0128 - accuracy: 0.9990
# Epoch 35/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.1239 - accuracy: 0.9777
# Epoch 36/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0933 - accuracy: 0.9758
# Epoch 37/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0061 - accuracy: 0.9995
# Epoch 38/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1285 - accuracy: 0.9713
# Epoch 39/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0104 - accuracy: 0.9990
# Epoch 40/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.2202 - accuracy: 0.9684
# Epoch 41/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0074 - accuracy: 0.9993
# Epoch 42/200
# 33/33 [==============================] - 1s 22ms/step - loss: 0.1527 - accuracy: 0.9669
# Epoch 43/200
# 33/33 [==============================] - 1s 22ms/step - loss: 0.0205 - accuracy: 0.9950
# Epoch 44/200
# 33/33 [==============================] - 1s 22ms/step - loss: 0.0769 - accuracy: 0.9796
# Epoch 45/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0290 - accuracy: 0.9921
# Epoch 46/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1105 - accuracy: 0.9835
# Epoch 47/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1700 - accuracy: 0.9631
# Epoch 48/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0094 - accuracy: 0.9988
# Epoch 49/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1156 - accuracy: 0.9818
# Epoch 50/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0065 - accuracy: 0.9988
# Epoch 51/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.1758 - accuracy: 0.9689
# Epoch 52/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0057 - accuracy: 0.9995
# Epoch 53/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.1163 - accuracy: 0.9825
# Epoch 54/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0055 - accuracy: 0.9988
# Epoch 55/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0063 - accuracy: 0.9990
# Epoch 56/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1408 - accuracy: 0.9744
# Epoch 57/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0054 - accuracy: 0.9993
# Epoch 58/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0744 - accuracy: 0.9866
# Epoch 59/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0252 - accuracy: 0.9945
# Epoch 60/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0869 - accuracy: 0.9828
# Epoch 61/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0110 - accuracy: 0.9971
# Epoch 62/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1762 - accuracy: 0.9749
# Epoch 63/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0391 - accuracy: 0.9904
# Epoch 64/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0041 - accuracy: 0.9993
# Epoch 65/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0672 - accuracy: 0.9844
# Epoch 66/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0026 - accuracy: 0.9993
# Epoch 67/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1155 - accuracy: 0.9780
# Epoch 68/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0040 - accuracy: 0.9993
# Epoch 69/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0036 - accuracy: 0.9988
# Epoch 70/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0851 - accuracy: 0.9806
# Epoch 71/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0186 - accuracy: 0.9966
# Epoch 72/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1704 - accuracy: 0.9758
# Epoch 73/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0031 - accuracy: 0.9990
# Epoch 74/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1482 - accuracy: 0.9749
# Epoch 75/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0029 - accuracy: 0.9993
# Epoch 76/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0873 - accuracy: 0.9775
# Epoch 77/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0027 - accuracy: 0.9993
# Epoch 78/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.2592 - accuracy: 0.9698
# Epoch 79/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0120 - accuracy: 0.9974
# Epoch 80/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0030 - accuracy: 0.9990
# Epoch 81/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.1815 - accuracy: 0.9689
# Epoch 82/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0037 - accuracy: 0.9993
# Epoch 83/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0023 - accuracy: 0.9993
# Epoch 84/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.1408 - accuracy: 0.9768
# Epoch 85/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0043 - accuracy: 0.9988
# Epoch 86/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0928 - accuracy: 0.9811
# Epoch 87/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0028 - accuracy: 0.9993
# Epoch 88/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1681 - accuracy: 0.9722
# Epoch 89/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0020 - accuracy: 0.9995
# Epoch 90/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0823 - accuracy: 0.9863
# Epoch 91/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0073 - accuracy: 0.9981
# Epoch 92/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0020 - accuracy: 0.9993
# Epoch 93/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1057 - accuracy: 0.9777
# Epoch 94/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0023 - accuracy: 0.9993
# Epoch 95/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0662 - accuracy: 0.9873
# Epoch 96/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0025 - accuracy: 0.9993
# Epoch 97/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0026 - accuracy: 0.9990
# Epoch 98/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.1296 - accuracy: 0.9780
# Epoch 99/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0028 - accuracy: 0.9993
# Epoch 100/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0027 - accuracy: 0.9993
# Epoch 101/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1042 - accuracy: 0.9775
# Epoch 102/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0020 - accuracy: 0.9993
# Epoch 103/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0804 - accuracy: 0.9847
# Epoch 104/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0034 - accuracy: 0.9990
# Epoch 105/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0018 - accuracy: 0.9995
# Epoch 106/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1445 - accuracy: 0.9727
# Epoch 107/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0024 - accuracy: 0.9993
# Epoch 108/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1090 - accuracy: 0.9811
# Epoch 109/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0058 - accuracy: 0.9988
# Epoch 110/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0020 - accuracy: 0.9995
# Epoch 111/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0949 - accuracy: 0.9816
# Epoch 112/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0018 - accuracy: 0.9993
# Epoch 113/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1601 - accuracy: 0.9717
# Epoch 114/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0015 - accuracy: 0.9993
# Epoch 115/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0014 - accuracy: 0.9995
# Epoch 116/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0784 - accuracy: 0.9847
# Epoch 117/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0318 - accuracy: 0.9904
# Epoch 118/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0117 - accuracy: 0.9966
# Epoch 119/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0025 - accuracy: 0.9993
# Epoch 120/200
# 33/33 [==============================] - 1s 22ms/step - loss: 0.2077 - accuracy: 0.9760
# Epoch 121/200
# 33/33 [==============================] - 1s 21ms/step - loss: 0.0017 - accuracy: 0.9993
# Epoch 122/200
# 33/33 [==============================] - 1s 22ms/step - loss: 0.0018 - accuracy: 0.9995
# Epoch 123/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1173 - accuracy: 0.9813
# Epoch 124/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0021 - accuracy: 0.9995
# Epoch 125/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0024 - accuracy: 0.9990
# Epoch 126/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0619 - accuracy: 0.9868
# Epoch 127/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0019 - accuracy: 0.9995
# Epoch 128/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1084 - accuracy: 0.9801
# Epoch 129/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0016 - accuracy: 0.9993
# Epoch 130/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0020 - accuracy: 0.9990
# Epoch 131/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1020 - accuracy: 0.9851
# Epoch 132/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0024 - accuracy: 0.9995
# Epoch 133/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.1265 - accuracy: 0.9813
# Epoch 134/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0042 - accuracy: 0.9988
# Epoch 135/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0024 - accuracy: 0.9990
# Epoch 136/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1841 - accuracy: 0.9744
# Epoch 137/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0021 - accuracy: 0.9995
# Epoch 138/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0014 - accuracy: 0.9993
# Epoch 139/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.2152 - accuracy: 0.9732
# Epoch 140/200
# 33/33 [==============================] - 1s 21ms/step - loss: 0.0024 - accuracy: 0.9988
# Epoch 141/200
# 33/33 [==============================] - 1s 21ms/step - loss: 0.0032 - accuracy: 0.9990
# Epoch 142/200
# 33/33 [==============================] - 1s 21ms/step - loss: 0.1010 - accuracy: 0.9820
# Epoch 143/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0015 - accuracy: 0.9993
# Epoch 144/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1691 - accuracy: 0.9801
# Epoch 145/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0020 - accuracy: 0.9993
# Epoch 146/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0017 - accuracy: 0.9993
# Epoch 147/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1420 - accuracy: 0.9799
# Epoch 148/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0023 - accuracy: 0.9993
# Epoch 149/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0032 - accuracy: 0.9990
# Epoch 150/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1360 - accuracy: 0.9813
# Epoch 151/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0012 - accuracy: 0.9993
# Epoch 152/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1367 - accuracy: 0.9808
# Epoch 153/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0034 - accuracy: 0.9988
# Epoch 154/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0014 - accuracy: 0.9995
# Epoch 155/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0943 - accuracy: 0.9851
# Epoch 156/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0018 - accuracy: 0.9993
# Epoch 157/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0783 - accuracy: 0.9871
# Epoch 158/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0021 - accuracy: 0.9990
# Epoch 159/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0017 - accuracy: 0.9993
# Epoch 160/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1422 - accuracy: 0.9820
# Epoch 161/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0021 - accuracy: 0.9990
# Epoch 162/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0020 - accuracy: 0.9995
# Epoch 163/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0678 - accuracy: 0.9863
# Epoch 164/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0701 - accuracy: 0.9842
# Epoch 165/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0046 - accuracy: 0.9981
# Epoch 166/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0012 - accuracy: 0.9993
# Epoch 167/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0515 - accuracy: 0.9856
# Epoch 168/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0011 - accuracy: 0.9990
# Epoch 169/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0410 - accuracy: 0.9899
# Epoch 170/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0014 - accuracy: 0.9993
# Epoch 171/200
# 33/33 [==============================] - 1s 20ms/step - loss: 8.5306e-04 - accuracy: 0.9995
# Epoch 172/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0997 - accuracy: 0.9849
# Epoch 173/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0020 - accuracy: 0.9993
# Epoch 174/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0015 - accuracy: 0.9995
# Epoch 175/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0734 - accuracy: 0.9890
# Epoch 176/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0058 - accuracy: 0.9978
# Epoch 177/200
# 33/33 [==============================] - 1s 19ms/step - loss: 9.1628e-04 - accuracy: 0.9993
# Epoch 178/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.1363 - accuracy: 0.9840
# Epoch 179/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0012 - accuracy: 0.9993
# Epoch 180/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0016 - accuracy: 0.9995
# Epoch 181/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0201 - accuracy: 0.9931
# Epoch 182/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0215 - accuracy: 0.9947
# Epoch 183/200
# 33/33 [==============================] - 1s 20ms/step - loss: 9.7744e-04 - accuracy: 0.9993
# Epoch 184/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0011 - accuracy: 0.9993
# Epoch 185/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0617 - accuracy: 0.9897
# Epoch 186/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0011 - accuracy: 0.9995
# Epoch 187/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0401 - accuracy: 0.9916
# Epoch 188/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0012 - accuracy: 0.9990
# Epoch 189/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0410 - accuracy: 0.9899
# Epoch 190/200
# 33/33 [==============================] - 1s 19ms/step - loss: 0.0025 - accuracy: 0.9983
# Epoch 191/200
# 33/33 [==============================] - 1s 20ms/step - loss: 9.7419e-04 - accuracy: 0.9993
# Epoch 192/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0322 - accuracy: 0.9921
# Epoch 193/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0017 - accuracy: 0.9993
# Epoch 194/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0814 - accuracy: 0.9866
# Epoch 195/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0015 - accuracy: 0.9993
# Epoch 196/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0272 - accuracy: 0.9935
# Epoch 197/200
# 33/33 [==============================] - 1s 20ms/step - loss: 0.0020 - accuracy: 0.9990
# Epoch 198/200
# 33/33 [==============================] - 1s 22ms/step - loss: 0.1061 - accuracy: 0.9842
# Epoch 199/200
# 33/33 [==============================] - 1s 22ms/step - loss: 0.0013 - accuracy: 0.9993
# Epoch 200/200
# 33/33 [==============================] - 1s 23ms/step - loss: 8.9522e-04 - accuracy: 0.9990

# %%
model.evaluate(X_test, y_test)
# Out:
# 33/33 [==============================] - 0s 7ms/step - loss: 4.7131 - accuracy: 0.5824
# [4.713069915771484, 0.5823754668235779]

# %%
import cv2
# url = 'download (5).jpeg'
# n=2
n = 3
images_test = list(Path('/content/vietnamese-foods/Images/Train/Bun bo Hue/').glob('*g'))
# print(images_test)
url = images_test[n]
image = cv2.imread(str(url))
img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.imshow(img)
img = cv2.resize(img, (64,64))
img = img.astype('float32')/255
print(img.shape)
pred = model.predict(img.reshape((1, 64, 64, 3)))
print(food[pred.argmax()])
# Out:
# (64, 64, 3)
# 1/1 [==============================] - 0s 150ms/step
# Banh duc
